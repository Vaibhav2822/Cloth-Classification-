# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhav2822/Cloth-Classification-/blob/main/Cloth_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
data = keras.datasets.fashion_mnist

# %%
(train_images,train_labels),(test_images,test_labels) = data.load_data()
# Out:
# ...
# 4423680/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top','Trouser','Pullover','Dress','Coat','Sandal','Shirt','Sneaker','Bag','Ankle boot']

# %%
train_images =train_images/255.0
test_images = test_images/255.0

# %% [markdown]
# # Taking N Inputs

# %%
for i in range(5):
    plt.imshow(train_images[i],cmap='gray') 
    plt.xlabel(class_names[test_labels[i]])
    plt.show()

# %% [markdown]
# # Defining Model

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),   
    keras.layers.Dense(128 , activation = 'relu'),  
    keras.layers.Dense(10 , activation='softmax')    
])

# %% [markdown]
# #  Model Training

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.fit(train_images,train_labels,epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5012 - accuracy: 0.8230
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3739 - accuracy: 0.8661
# Epoch 3/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3364 - accuracy: 0.8769
# Epoch 4/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3120 - accuracy: 0.8874
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2941 - accuracy: 0.8924
# Epoch 6/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2805 - accuracy: 0.8970
# Epoch 7/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2686 - accuracy: 0.9013
# Epoch 8/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2562 - accuracy: 0.9043
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2486 - accuracy: 0.9066
# Epoch 10/10
# ...

# %% [markdown]
# # Testing Data Accuracy

# %%
test_loss , test_acc = model.evaluate(test_images,test_labels) 
print("Testing Accuracy:",test_acc)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.3452 - accuracy: 0.8775
# Testing Accuracy: 0.8774999976158142

# %% [markdown]
# # Prediction with Single Testing Data

# %%
prediction = model.predict(test_images)  
plt.imshow(test_images[2],cmap='gray')
plt.title("Actual Image:" + class_names[test_labels[2]])
plt.show()
print(np.argmax(prediction[2])) 
print('Predicted Image:' + class_names[np.argmax(prediction[2])])
# Out:
# 1
# Predicted Image:Trouser

# %% [markdown]
# # Predicting Testing Models

# %%
prediction = model.predict(test_images)
for i in range(5): 
    plt.imshow(test_images[i],cmap='gray') 
    plt.xlabel('Actual:'+ class_names[test_labels[i]]) 
    plt.title('Prediction:'+ class_names[np.argmax(prediction[i])])
    plt.show()

# %% [markdown]
# # Training Data Accuracy

# %%
train_loss , train_acc = model.evaluate(train_images,train_labels) 
print("Training Accuracy:",train_acc)
# Out:
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2323 - accuracy: 0.9128
# Training Accuracy: 0.912766695022583

# %% [markdown]
# # Prediction with Single Training Data

# %%
prediction = model.predict(train_images)
plt.imshow(train_images[2],cmap='gray')
plt.title("Actual Image:" +class_names[train_labels[2]])
plt.show()
print(np.argmax(prediction[2])) 
print('Predicted Image:'+class_names[np.argmax(prediction[2])])
# Out:
# 3
# Predicted Image:Dress

# %% [markdown]
# # Predicting Training Model

# %%
prediction = model.predict(train_images)
for i in range(5): 
    plt.imshow(train_images[i],cmap='gray') 
    plt.xlabel('Actual:'+ class_names[train_labels[i]]) 
    plt.title('Prediction:'+ class_names[np.argmax(prediction[i])]) 
    plt.show()
